# %% [markdown]
# # __IMPORT THE NECESSARY MODULES & PACKAGES__

# %%
# Impoiting libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import math
import matplotlib

# %% [markdown]
# ## checking the version of packages

# %%
print(f"Pandas Version : Pandas{pd.__version__}")
print(f"Numpy Version :Numpy{np.__version__}")
print(f"Matplotlib Version : Matplotlib {matplotlib.__version__}")
print(f"Seaborn Version : Seaborn {sns.__version__}")

# Magic Function for In=Notebook Display

# %matplotlib inline
# Out:
# Pandas Version : Pandas1.0.1
# Numpy Version :Numpy1.18.1
# Matplotlib Version : Matplotlib 3.1.3
# Seaborn Version : Seaborn 0.10.0

# %% [markdown]
# ## Importing the Data set

# %%
df=pd.read_csv('creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
# in the agbove codes result we can see that the columns between v9 to v21 are not visible 
# they are covered by ... 3 dots. to make them visible we can do the following

# %%
# showing 100 columns and 100 rows
pd.options.display.max_rows=100
pd.options.display.max_columns=100

# %%
# now we can see all the columns
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
#the PCA features we can't do much with it nither we can live them 
# mainly we will work with 'Amount', 'Time','Class'
# where class is indipendent and rest is dependent
# in class 1 stands for fraud and 0 stands for not fraud

# %%
# Converting all the coumn names to lower case
df.columns=df.columns.str.lower()

# %%
df.head()
# Out:
#    time        v1        v2        v3        v4        v5        v6        v7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          v8        v9       v10       v11       v12       v13       v14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
df.columns
# Out:
# Index(['time', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6', 'v7', 'v8', 'v9', 'v10',
#        'v11', 'v12', 'v13', 'v14', 'v15', 'v16', 'v17', 'v18', 'v19', 'v20',
#        'v21', 'v22', 'v23', 'v24', 'v25', 'v26', 'v27', 'v28', 'amount',
#        'class'],
#       dtype='object')

# %%
# it is said that features form v1 to v28 are PCA features
# what is PCA? --> PCA creates indipendent vectors based on eigne(proper) vectors (so very low correletions)
# the PCA features we can't do much with it nither we can live them 
# mainly we will work with 'Amount', 'Time','Class'
# where "class" is dependent and rest is indipendent
# in "class", 1 stands for fraud and 0 stands for not fraud

# %% [markdown]
# # Exploratory Data Analysis (__EDA__)

# %%
### here our target is not to miss out any pattern, we must try all the possible pattarn within this 3 columns
#### After importing the data in to python we need to explore the data.
#### Cleaning, filtering, adding & removing of columns and rows, so we need to check our data.

# %% [markdown]
# ### Treating the Null values

# %%
# finding out the Null values
df.isnull().sum()
# Out:
# time      0
# v1        0
# v2        0
# v3        0
# v4        0
# v5        0
# v6        0
# v7        0
# v8        0
# v9        0
# v10       0
# v11       0
# v12       0
# v13       0
# v14       0
# v15       0
# v16       0
# v17       0
# v18       0
# v19       0
# v20       0
# v21       0
# v22       0
# v23       0
# v24       0
# v25       0
# v26       0
# v27       0
# v28       0
# amount    0
# class     0
# dtype: int64

# %%
# data type of all the features and checking the Null Values of all the features
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   time    284807 non-null  float64
#  1   v1      284807 non-null  float64
#  2   v2      284807 non-null  float64
#  3   v3      284807 non-null  float64
#  4   v4      284807 non-null  float64
#  5   v5      284807 non-null  float64
#  6   v6      284807 non-null  float64
#  7   v7      284807 non-null  float64
#  8   v8      284807 non-null  float64
#  9   v9      284807 non-null  float64
#  10  v10     284807 non-null  float64
#  11  v11     284807 non-null  float64
#  12  v12     284807 non-null  float64
#  13  v13     284807 non-null  float64
#  14  v14     284807 non-null  float64
#  15  v15     284807 non-null  float64
#  16  v16     284807 non-null  float64
#  17  v17     284807 non-null  float64
#  18  v18     284807 non-null  float64
#  19  v19     284807 non-null  float64
# ...

# %%
# so there is no null value. 
# it has 284807 transactions(rows) and 31 features(columns)
# all features are numeric data type.

# %%
# we will count how many fraud and genuine transactions took place
# on the beasis of feature 'class' where 1 stands for fraud and 0 stands for geniune transections. 
df['class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: class, dtype: int64

# %%
# we can see the number of fraud transection is very less in respect of geniune transection 
# we will check the parcentage of the each type of transection.
df['class'].value_counts(normalize=True)
# Out:
# 0    0.998273
# 1    0.001727
# Name: class, dtype: float64

# %%
# so the parcentage are 99.8273% are geniune transaction and 0.1727% are fraud transaction
# which is a highly "IMBALANCED" data, 
# if we train our model with this "IMBALANCED" data our model will be biosed towords the geniune transection.
#so we will have to handel the data imbalance.

# %%
# nwo we will check the maximum vlaue of amount to see if it is an outlier or not
df['amount'].max()
# Out:
# 25691.16

# %%
# nwo we will check the maximum vlaue of amount to see if it is an outlier or not
df['amount'].min()
# Out:
# 0.0

# %%
# our data range is in between 0 to 25691.16 which is a big range for bank transaction
# so it feels like our max value is an outlier, we will check it.

# %%
# now we will check the description of 'amount' column to see how far is the maximumvalue form the Q3(75%)
df['amount'].describe()
# Out:
# count    284807.000000
# mean         88.349619
# std         250.120109
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.165000
# max       25691.160000
# Name: amount, dtype: float64

# %%
# as we can see the Q3 is 77.165 and the max value is 25691.16 so it is an outliers

# %%
# for more clearer understanding we will check the description of our 3 column with transpose view
df[['amount','class','time']].describe().T
# Out:
#            count          mean           std  min      25%      50%  \
# amount  284807.0     88.349619    250.120109  0.0      5.6     22.0
# class   284807.0      0.001727      0.041527  0.0      0.0      0.0
# time    284807.0  94813.859575  47488.145955  0.0  54201.5  84692.0
#
#                75%        max
# amount      77.165   25691.16
# class        0.000       1.00
# time    139320.500  172792.00

# %%
# ovservasion
# lookin at the numbers we can say that
# a fraud transection is happening every 94813.86 seconds
# average transection value is 88.3496, 
# std of amount is 250,minimum value 0, maximum value 25691.16
# looks like the data is positively skewed

# %% [markdown]
# ### Treatment of the ZERO values

# %%
# Before removing any thing we must remember the golden rule of data science
# we should not loos data, always we should keep more data in our hand.
# any data which is absulately none of our use we can loos that much only
# like exact duplicate etc.

# %%
# let's find out total number of transaction that has '0' in amount value
len(df[(df['amount']==0)])
# Out:
# 1825

# %%
# let's find out total number of transaction which has a value of 0 in "amount" and "0" in "Class"
# that is amount 0 in geniune transections.
len(df[(df['amount']==0) & (df['class']==0)])
# Out:
# 1798

# %%
# let's find out total number of transaction which has 0 in "amount" and 0 in "class"
# that is amount in fraud transactions.
len(df[(df['amount']==0) & (df['class']==1)])
# Out:
# 27

# %%
# let's check our total number of rows and columns
df.shape
# Out:
# (284807, 31)

# %%
# if we remove 0 value transaction of the genuine transactions then 
# what is the parcentage of data we will loose

len(df[(df['amount']==0) & (df['class']==0)])/len(df)
# Out:
# 0.006313047081005734

# %%
# we will loose 0.631% of the data
# but in would not be a good idea to remove them 
# becasu other than amount and class column
# there could be some importent pattern in the other columns of the row
# so we will not remove it

# %% [markdown]
# ### Removing the duplicate data

# %%
# first we will cekeck the nubmer of rows with duplicate data.
print(len(df[df.duplicated()]))
# Out:
# 1081

# %%
#let's check how many are duplicate data in geniune transactions. 
print(len(df[df.duplicated() & (df['class']==0)]))
# Out:
# 1062

# %%
#let's check how many are duplicate data in fraud transactions. 
print(len(df[df.duplicated() & (df['class']==1)]))

# they are only 19 in number so it is alright in loosing them.
# Out:
# 19

# %%
# we will ceheck the number of total rows using shape
df.shape
# Out:
# (284807, 31)

# %%
# percentage of data loss if we remove the duplicate values of the geniune transactions only
len(df[df.duplicated() & (df['class']==0)])/len(df)
# Out:
# 0.0037288409343871464

# %%
# percentage of data loss if we remove all the duplicate values
len(df[df.duplicated()])/len(df)
# Out:
# 0.00379555277784605

# %%
# percentage of data loss if we remove the duplicate of geniune transactirons 1062/284807=0.3728% not much of data
# percentage of data loss if we remove all the duplicate values 1081/284807=0.3795% it increases the data loos by
# a very less amount of data.
# we do not want to feed our model duplicate data so we will loos the duplicate data. 
# this is an acceptable data loss %, so we can remove it.

# %%
df.duplicated().value_counts()
# False means unique rows (False according to our code)
# True means duplicate rows J(True according to our code)
# Out:
# False    283726
# True       1081
# dtype: int64

# %%
# taking a backup berore removing
df1=df

# %%
df1.head(1)
# Out:
#    time        v1        v2        v3        v4        v5        v6        v7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
#
#          v8        v9       v10     v11       v12      v13       v14  \
# 0  0.098698  0.363787  0.090794 -0.5516 -0.617801 -0.99139 -0.311169
#
#         v15       v16       v17       v18       v19       v20       v21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
#
#         v22       v23       v24       v25       v26       v27       v28  \
# 0  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
#
#    amount  class
# 0  149.62      0

# %%
# REMOVING THE DUPLICATE ROWS
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (283726, 31)

# %%
# previously our data set had 284807 rows now it has 283726 so it is a data loos of 1081 rows.

# %%
# after removing any thing we need to reset the index

df.reset_index(drop = True , inplace = True)

# %% [markdown]
# ## Distribution of Fradulent and genuine transaction

# %%
plt.style.use("ggplot")
plt.figure(figsize=(8,6))
plt.title('Distribution of Genuine Transaction Amount',fontsize=14)
sns.distplot(df[df['class']==0]['amount'],bins=50)
plt.plot()
# Distribution of geniune transactions amount.
# Out:
# []

# %%
# we can see most of the geniune transaction happens within around 600 Euros.
# and the highest is more than 25000 Euros

# %%
plt.figure(figsize=(8,6))
plt.title('Distribution of Fraud Transaction Amount',fontsize=14)
sns.distplot(df[df['class']==1]['amount'],bins=100)
plt.grid(True)
plt.plot()
# Out:
# []

# %%
# we can see most of the fraud transaction happens within around 250 Euros.
# and the highest is more than 2000 Euros

# %%
# highest genuine transaction
df[df['class']==0]['amount'].max()
# Out:
# 25691.16

# %%
# highest Fraud Transaction
df[df['class']==1]['amount'].max()
# Out:
# 2125.87

# %% [markdown]
# ### Treating the outliers

# %%
# we will check the outliers and we will find out the parcengtage of data lose 
# we will remove the outliers depending on the data loss parcentage
# we can't loos data more than 5% at any point.

# %%
# we will check the outlier using box plot class wise
plt.figure(figsize = (8,4) , dpi = 100) # this line of code for more clearer image
sns.boxplot(x='class',y='amount',data=df)
plt.show()

# %%
# the image shows distribution of data class wise, 
# here we can easyly understand that there are more outliers in geniune transactions
# fraud transactions has less number of outliers 
# The amount of fraud transaction are less than 5000 euros.

# %%
# our aim is to detect the fraud transaction 
# in our data fraud transactions has only 0.1727% which is very very low in numbers.
# keeping it in mind we should not loose any data from the fraud transaction side.
# so in outlier removal we will set our upper bound to the maximum value of fraud transactions.
# but we will also look at the data that how much % of data we loose if we remove the outlier using contemporary method.

# %%
# we will write a function to find out the outliers using contemporary method. 
def indicies_of_outliers(x):
    q1,q3=np.percentile(x,[25,75])
    iqr=q3-q1
    lower_bound=q1-(iqr*1.5)
    upper_bound=q3+(iqr*1.5)
    
    return np.where((x > upper_bound)|(x < lower_bound))

# %%
indicies_of_outliers(df['amount'])
# this are the index value of the outliers
# Out:
# (array([     2,     20,     49, ..., 283672, 283676, 283725], dtype=int64),)

# %%
# counting how many outliers are there
len(indicies_of_outliers(df['amount'])[0])
# Out:
# 31685

# %%
# total how many data points we have
len(df)
# Out:
# 283726

# %%
# lets check what parcentage of data we will loose if we just directly remove the outlier
len(indicies_of_outliers(df['amount'])[0])/len(df)
# Out:
# 0.11167464384652799

# %%
# so if we drop outliers directly then we loose 11.18% of the data
# we could end up loosing outlier fraud transaction. which we can't effort to do.
# a good number of outlier removed would be 5-6 %

# %%
# in case of an unbalanced data the proportion of 0 & 1 should be similar
# before and after the removal of outlier.
# lets check the propotion before and after removing the outliers

# %%
# propotion of 0 & 1 before removal of outlier
df['class'].value_counts(normalize=True)
# Out:
# 0    0.998333
# 1    0.001667
# Name: class, dtype: float64

# %%
# propotion of 0 & 1 after removal of outliers
df[df.index.isin(list(indicies_of_outliers(df['amount'])[0]))]['class'].value_counts(normalize = True)
# Out:
# 0    0.997254
# 1    0.002746
# Name: class, dtype: float64

# %%
# there is a difference betweent the before and after removal proportion of 0 & 1 values
# but this difference is not significent, but in this way we will loose the fraud transaction ouliers as well
# and our data is already short form the fraud side.
# so we can't loos data from the fraud side

# %%
# in the process of removing anyting form the DF if the proportion of class changes significently 
# in before removal and after removal that means 
# there is an interesting pattern we are missing out

# %%
# number of outliers in the fraud transaction side and geniune transaction side. 
df[df.index.isin(list(indicies_of_outliers(df['amount'])[0]))]['class'].value_counts()
# Out:
# 0    31598
# 1       87
# Name: class, dtype: int64

# %%
# if we remove outlier on the basis of this calculation then
# we loose 87 data point of the fraud transactions
# we can't loose this much of data form the fraud transaction. 
# so we will set our upper bound to the maximum value of fraud transaction.
# this way we would not loose any data form the fraud transaction side.

# %%
# Maximum value of a fraud transection (this is the max_val)
# this one would be our upper bound limit
df[df['class']==1]['amount'].max()
# Out:
# 2125.87

# %%
# we will store this in to max_val
max_val=df[df['class']==1]['amount'].max()

# %%
# total number of outlier in the upper side
len(df[df['amount']>max_val])
# Out:
# 603

# %%
# if we remove outliers this way, we loose 603 rows.

# %%
# Percentage of data loss if we remove outliers in this way. 
len(df[df['amount']>max_val])/len(df)
# Out:
# 0.0021252898923609397

# %%
# the loss is 0.21%  which is a small number so we can remove the outliers.

# %%
# Allthough we are removing the outlier form the geniune side only still we need to check the 
# proportion of data before and after loosing the data

# %%
# removing the outliers of the upper side and store it to temp_df (this will help us to calculate the 
# data loos proportion)
temp_df=df[df['amount']<max_val]

# %%
# after removing any thing we need to reset the index

temp_df.reset_index(drop = True , inplace = True)

# %%
# Proportion of '0' & '1' before removal of outliers
df['class'].value_counts(normalize=True)
# Out:
# 0    0.998333
# 1    0.001667
# Name: class, dtype: float64

# %%
# Proportion of '0' & '1' after removal of outliers
temp_df['class'].value_counts(normalize=True)
# Out:
# 0    0.998333
# 1    0.001667
# Name: class, dtype: float64

# %%
type(temp_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# it shows no difference because it is a very little change.
# to confirm if they are removed or not we will check the shape of both df.

# %%
# shape of DF
df.shape
# Out:
# (283726, 31)

# %%
# shape of temporary DF
temp_df.shape
# Out:
# (283122, 31)

# %%
# here we can see that the outliers are removed

# %%
# Amount column before removing outliers
plt.boxplot(df['amount'])
plt.show()

# %%
# Amount column after removing outliers
plt.boxplot(temp_df['amount'])
plt.show()

# %%
# we can se the change in the boxplot.

# %%
# in our actual df the maximum value gose more than 25000 
# but in outlier removed temp_df the maximum value goes till 2125

# %%
# Now we will start checking the lower bound for outliers.

# %%
# checking the temp_df manually if we find any thing significent in the lower side of the data
q1,q3=np.percentile(temp_df['amount'],[25,75])

# %%
q1
# like we have seen in the describe()
# Out:
# 5.5225

# %%
q3
# like we have seen in the describe()
# Out:
# 76.73

# %%
# now we will find the iqr
iqr=q3-q1

# %%
iqr
# Out:
# 71.20750000000001

# %%
upper_bound=q3+(iqr*1.5)

# %%
upper_bound
# Out:
# 183.54125000000002

# %%
lower_bound=q1-(iqr*1.5)

# %%
lower_bound
# Out:
# -101.28875000000002

# %%
# as the lower bound of the data set shows a negetive value
# now we need to check if there is any negetive value transaction in our data
df[df['amount']<0]
# Out:
# Empty DataFrame
# Columns: [time, v1, v2, v3, v4, v5, v6, v7, v8, v9, v10, v11, v12, v13, v14, v15, v16, v17, v18, v19, v20, v21, v22, v23, v24, v25, v26, v27, v28, amount, class]
# Index: []

# %%
# it shwos there is no negetive value transaaction. 
# so we can bring our lower bound to 0

# %%
# if we remove the zero value transactions then we loos the zero value fraud transactions as well
# here we are removing the 0 value transaction of the geniune side only.

# %%
type(temp_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### Removing the ZERO vales of geniune transactions

# %%
# now we need to filter our temp_df where class is "0" and amount is less than "0"
# so ther eare two conditions
# if we do this, this will convert the result to a pandas boolien series.
# so, we will make "mask" according to the condition. 1 mask for one condition
# then we will put all the mask on top of the data frame using "&" and we will find our answer.

# %%
mask1=temp_df['class']==0
mask2=temp_df['amount']>0
mask3=temp_df["class"]==1

# %%
temp_df[mask1 & mask2 | mask3]
# Out:
#             time         v1         v2        v3        v4        v5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 283721  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 283722  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 283723  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 283724  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 283725  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               v6        v7        v8        v9       v10       v11       v12  \
# ...

# %%
# storing the geniune 0 value transections removed data to dfs
dfs=temp_df[mask1 & mask2 | mask3]

# %%
type(dfs)
# Out:
# pandas.core.frame.DataFrame

# %%
# mask=temp_df[temp_df['class']==0]['amount']>0
# this code will not work because our code has 3 conditions (more than 1 condition), 
# the result will be a boolien series
# more than 1 condition used boolien series will work but the indix number will be redused
# and the mask would not match the data frame so it would not work. 
# if it was only one condition then this would have workde. 
# so we have to creat one mask for each condition. 
# and put all the masks on top of the data frame using "&" to get the out put as a data frame

# %%
temp_df.shape
# Out:
# (283122, 31)

# %%
dfs.shape
# Out:
# (281339, 31)

# %%
# lets have a look how many fraud and geniune transaction are there after removal. 
dfs['class'].value_counts()
# Out:
# 0    280867
# 1       472
# Name: class, dtype: int64

# %%
# lets check the proportion of fraud and geniune transactions before and after removal. 
dfs['class'].value_counts(normalize=True)
# Out:
# 0    0.998322
# 1    0.001678
# Name: class, dtype: float64

# %%
temp_df['class'].value_counts(normalize=True)
# Out:
# 0    0.998333
# 1    0.001667
# Name: class, dtype: float64

# %%
# the numbers are very similar so we are good to go.

# %%
# lets check how many are fraud transaction but 0 in amount.
len(dfs[(dfs['amount']==0) & (dfs['class']==1)])
# Out:
# 25

# %%
# after removing any thing we need to reset the index

dfs.reset_index(drop = True , inplace = True)

# %%
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: amount, dtype: bool

# %% [markdown]
# ### Time Column

# %% [markdown]
# #### Distribution of Time

# %%
plt.figure(figsize=(8,6))
plt.title('Distribution of transaction time',fontsize=14)
sns.distplot(dfs['time'],bins=50)
plt.grid(True)
plt.plot()
# Out:
# []

# %%
# first the transaction starts increasing in the morning then 
# as the day ends transactions decreases 
# in the next morning the transactions starts increasing 
# and as the day ends the transactions decreases.

# %% [markdown]
# #### Distribution of time W.R.T genuine transaction

# %%
plt.style.use('ggplot')
plt.figure(figsize=(8,6))
plt.title('Distribution of time W.R.T Genuine transaction')
sns.distplot(dfs[(dfs['class']==0)]['time'], bins=50)
plt.plot()
# Out:
# []

# %%
# not much difference could be observed as most of the data are genuine. 
# we should check the time distribution w.r.t Fraud transaction

# %% [markdown]
# #### Distribution of time W.R.T Fraud transaction

# %%
plt.style.use('classic')
plt.figure(figsize=(8,6))
plt.title('Distribution W.R.T Fraud Transaction')
sns.distplot(dfs[(dfs['class']==1)]['time'], bins=100)
plt.plot()
# Out:
# []

# %%
# the graph show even at ninght time the number of fraud transactions dosen't fall much.

# %% [markdown]
# #### Distribution of Time W.R.T Class

# %%
plt.figure(figsize=(10,7))
plt.title('Distribution of Time w.r.t Fraud & Genuine transaction')
sns.boxplot(x='class',y='time',data=dfs)
plt.plot()
# Out:
# []

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# #### Time Column

# %%
plt.figsize = (20,20)
sns.distplot(dfs['time']) # No particular pattern as such , well distributed data
plt.show()

# %%
# Time plots 

fig , axs = plt.subplots(nrows = 1 , ncols = 2 , figsize = (15,8))


sns.distplot(dfs[dfs['class']==0]['hour'].values , color = 'blue' , ax = axs[0])
axs[0].set_title('Non Fraud Transactions')

sns.distplot(dfs[dfs['class']==1]['hour'].values , color = 'orange' ,ax = axs[1])
axs[1].set_title('Fraud Transactions')

fig.suptitle('Comparison between Transaction Frequencies vs Time for Fraud and Legit Transactions')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore') ## should use it

# %%
dfs['hour'] = dfs['time']/(3600) # We should use the %24 hours (we will do it later)
# in the data set the time is given as secends there  are 3600 secends in an hour 
# so we are deviding the secends by 3600 to convert it to hours.

# %%
dfs.head(1)
# Out:
#    time        v1        v2        v3        v4        v5        v6        v7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
#
#          v8        v9       v10     v11       v12      v13       v14  \
# 0  0.098698  0.363787  0.090794 -0.5516 -0.617801 -0.99139 -0.311169
#
#         v15       v16       v17       v18       v19       v20       v21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
#
#         v22       v23       v24       v25       v26       v27       v28  \
# 0  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
#
#    amount  class  hour
# 0  149.62      0   0.0

# %%
type(dfs)
# Out:
# pandas.core.frame.DataFrame

# %%
dfs.tail(1)
# Out:
#             time        v1        v2        v3        v4        v5        v6  \
# 281338  172792.0 -0.533413 -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               v7       v8       v9       v10       v11       v12       v13  \
# 281338  1.577006 -0.41465  0.48618 -0.915427 -1.040458 -0.031513 -0.188093
#
#              v14       v15      v16       v17      v18       v19       v20  \
# 281338 -0.084316  0.041333 -0.30262 -0.660377  0.16743 -0.256117  0.382948
#
#              v21       v22       v23       v24       v25       v26       v27  \
# 281338  0.261057  0.643078  0.376777  0.008797 -0.473649 -0.818267 -0.002415
#
#              v28  amount  class       hour
# 281338  0.013649   217.0      0  47.997778

# %%
dfs["hour"].tail(1)
# Out:
# 281338    47.997778
# Name: hour, dtype: float64

# %% [markdown]
# ### Class imbalance

# %%
plt.figsize = (20,20)
sns.countplot(dfs['class']) # Highly Skewed , Imbalanced Data
plt.title('Class Values Distribution')
plt.show()

# %%
# the class imbalance is so high here that the fraud transaction column is almost imvisible here

# %%
# we will try to follow the class imbalance using a pie chart
labels = ['Genuine ','Fraud ']
plt.pie(dfs['class'].value_counts(), labels=labels, autopct='%0.3f%%' , pctdistance=2.5, labeldistance=1.2)
plt.show()

# %%
dfs['class'].value_counts()
# Class 0 is Legitimate , Genuine Transactions
# Class 1 represents Fraudulent Transactions
# Out:
# 0    280867
# 1       472
# Name: class, dtype: int64

# %%
# lets have a look at the skewness percentage of the data
per_of_class_1 = dfs['class'].value_counts()[1] / len(df)
print("Skew Percentage , Less Dominant Class : {}".format(per_of_class_1))
# Out:
# Skew Percentage , Less Dominant Class : 0.0016635768311680987

# %% [markdown]
# ### Visualising Data for detecting any particular Pattern or Anomaly using Histogram Plots

# %%
dfs.hist(figsize = (25,25))
plt.show()

# %%
# we can see all the "PCA" columns are normally distributed.

# %% [markdown]
# #### Finding the correlaton among columns

# %%
df.corr()
# Out:
#             time        v1        v2        v3        v4        v5        v6  \
# time    1.000000  0.117927 -0.010556 -0.422054 -0.105845  0.173223 -0.063279
# v1      0.117927  1.000000  0.006875 -0.008112  0.002257 -0.007036  0.000413
# v2     -0.010556  0.006875  1.000000  0.005278 -0.001495  0.005210 -0.000594
# v3     -0.422054 -0.008112  0.005278  1.000000  0.002829 -0.006879 -0.001511
# v4     -0.105845  0.002257 -0.001495  0.002829  1.000000  0.001744 -0.000880
# v5      0.173223 -0.007036  0.005210 -0.006879  0.001744  1.000000 -0.000938
# v6     -0.063279  0.000413 -0.000594 -0.001511 -0.000880 -0.000938  1.000000
# v7      0.085335 -0.009173  0.007425 -0.011721  0.004657 -0.008709  0.000436
# v8     -0.038203 -0.001168  0.002899 -0.001815  0.000890  0.001430  0.003036
# v9     -0.007861  0.001828 -0.000274 -0.003579  0.002154 -0.001213 -0.000734
# v10     0.031068  0.000815  0.000620 -0.009632  0.002753 -0.006050 -0.002180
# ...

# %%
# Plotting a Correlation Plot to observe any correlations or patterns between the columns in the dataset.

corr_matrix = dfs.corr()
plot = plt.figure(figsize = (10,10))
sns.heatmap(corr_matrix) # seaborn Library
plt.show()

# %%
# correlation could be either positive or negative
# within the "PCA" columns there is very less correlation
# but almost all the "PCA" columns are prositively or negatively correlated 
# to our dependent and indipendent variables.

# %%
# Finally let's also plot a box plot for observing if columns have some outliers , 
#or a particular column is messy
for col in dfs.columns:
    plt.figure()
    dfs[col].plot(kind = 'box')

# %%
# all the columns other than time and hour have many outliers, but they are the "PCA" columns
# so we can't do much with them,
# the amount column, we have already taken care of it.

# %% [markdown]
# ### Processing the Data

# %% [markdown]
# ##### Processing the Time column

# %%
dfs["hour"]=dfs["hour"]%24 # as two day data

# %%
import math
dfs['hour'] = dfs['hour'].apply(lambda x : math.floor(x))

# %%
dfs.head()
# Out:
#    time        v1        v2        v3        v4        v5        v6        v7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          v8        v9       v10       v11       v12       v13       v14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
# Let's see if we find any particular pattern between time ( in hours ) and Fraud vs Legit Transactions

# matplotlib.pyplot as plt

plt.figure(figsize=(10,10)) # tuple of the figure size

sns.distplot(dfs[dfs['class'] == 0]["hour"], color='g') # Genuine - green

sns.distplot(dfs[dfs['class'] == 1]["hour"], color='r') # Fraudulent - Red

plt.title('Fraud vs Legit Transactions by Hours', fontsize=10)
plt.xlim([0,25])
plt.show()

# %%
# with a very small confidence we may say that Fraud transactions are more frequent towards the night , assumption
# But thats not significant enough

# %%
# Observing if there is nay patterns in Hour wise No. of Legit Transactions.

legit_hour_count = dfs[dfs['class']==0].groupby(['hour'] , as_index = False)['hour'].size().reset_index(name = 'count')

# %%
legit_hour_count
# Out:
#     hour  count
# 0      0   7565
# 1      1   4165
# 2      2   3233
# 3      3   3436
# 4      4   2149
# 5      5   2966
# 6      6   4052
# 7      7   7103
# 8      8  10149
# 9      9  15544
# 10    10  16351
# 11    11  16543
# 12    12  15227
# 13    13  15155
# 14    14  16339
# 15    15  16211
# 16    16  16254
# 17    17  15973
# 18    18  16823
# 19    19  15450
# 20    20  16577
# 21    21  17528
# 22    22  15285
# 23    23  10789

# %%
# Observing if there is nay patterns in Hour wise No. of Fraud Transactions.
fraud_hour_count = dfs[dfs['class']==1].groupby(['hour'] , as_index = False)['hour'].size().reset_index(name = 'count')

# %%
fraud_hour_count
# Out:
#     hour  count
# 0      0      6
# 1      1     10
# 2      2     48
# 3      3     17
# 4      4     23
# 5      5     11
# 6      6      9
# 7      7     23
# 8      8      9
# 9      9     16
# 10    10      7
# 11    11     53
# 12    12     17
# 13    13     17
# 14    14     23
# 15    15     26
# 16    16     22
# 17    17     28
# 18    18     28
# 19    19     19
# 20    20     18
# 21    21     16
# 22    22      9
# 23    23     17

# %%
legit_hour_count['count'].plot(kind = 'bar',color="g")

# %%
# as the starts teh legit transactions starts increasing 
# and it remains almost the same for the rest of the day till midnight

# %%
fraud_hour_count['count'].plot(kind = 'bar', color="b")

# %%
# Fraud transactions increases at 2 AM in the night and 11 AM in the day and gradually increases int he evening
# the pattern of fraud transactions is different than the legit transaction.

# %% [markdown]
# #### Scale the Amount Column

# %%
# StandardScaler RobustScaler MinmaxScaler

# %%
# importing StandardScaler from sklearn module library
from sklearn.preprocessing import StandardScaler 

ss = StandardScaler() # object of the class StandardScaler ()

# %%
# here we are scaleing the data. 
dfs['amount'].values.reshape(-1 , 1)
# Out:
# array([[149.62],
#        [  2.69],
#        [378.66],
#        ...,
#        [ 67.88],
#        [ 10.  ],
#        [217.  ]])

# %%
# Now we are fitting the StandardScaler
ss.fit_transform(dfs['amount'].values.reshape(-1,1))
# Out:
# array([[ 0.38381399],
#        [-0.44798903],
#        [ 1.68045976],
#        ...,
#        [-0.07893412],
#        [-0.40660551],
#        [ 0.76526697]])

# %%
# we are storing the scales (StandardScaler) data in to column of our data frame.
dfs['amount_scaled'] = ss.fit_transform(dfs['amount'].values.reshape(-1,1))

# %%
dfs.head(1)
# Out:
#    time        v1        v2        v3        v4        v5        v6        v7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
#
#          v8        v9       v10     v11       v12      v13       v14  \
# 0  0.098698  0.363787  0.090794 -0.5516 -0.617801 -0.99139 -0.311169
#
#         v15       v16       v17       v18       v19       v20       v21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
#
#         v22       v23       v24       v25       v26       v27       v28  \
# 0  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
#
#    amount  class  hour  amount_scaled
# 0  149.62      0     0       0.383814

# %% [markdown]
# #### Log transform our amount

# %%
# now we will log transform our amount comumn for a better output
dfs["amount_log"]=np.log(df.amount+0.01) # we need to add theis 0.01 because log transformation of 0 is not possible
# so the system will go mad.

# %%
dfs.head(1)
# Out:
#    time        v1        v2        v3        v4        v5        v6        v7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
#
#          v8        v9       v10     v11       v12      v13       v14  \
# 0  0.098698  0.363787  0.090794 -0.5516 -0.617801 -0.99139 -0.311169
#
#         v15       v16       v17       v18       v19       v20       v21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
#
#         v22       v23       v24       v25       v26       v27       v28  \
# 0  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
#
#    amount  class  hour  amount_scaled  amount_log
# 0  149.62      0     0       0.383814    5.008166

# %%
# we will visualise the data again with the log transformed data. and observed the difference
plt.figure(figsize=(14,6))
# Let's explore the Amount by Class and see the distribuition of Amount transactions
plt.subplot(121)
ax = sns.boxplot(x ="class",y="amount",
                 data=dfs)
ax.set_title("Class x Amount", fontsize=20)
ax.set_xlabel("with normal data", fontsize=16)
ax.set_ylabel("Amount", fontsize = 16)

plt.subplot(122)
ax1 = sns.boxplot(x ="class",y="amount_log", data=dfs)
ax1.set_title("Class x Amount", fontsize=20)
ax1.set_xlabel("with log data", fontsize=16)
ax1.set_ylabel("Amount(Log)", fontsize = 16)

plt.subplots_adjust(hspace = 0.6, top = 0.8)

plt.show()

# %%
# looking at the data it is clear that the log transformation makes the data more readable or more useable.

# %%
# now we will export our data to a csv file, which we will use in our machine learning.
dfs.to_csv("processed.csv",index=False)
